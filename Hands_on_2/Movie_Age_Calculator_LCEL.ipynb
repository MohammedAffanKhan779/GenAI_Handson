# %% [markdown]
# Name: Mohammed Affan Khan
#
# SRN: PES2UG23CS343
#
# Section: F

# %%
# %pip install python-dotenv --upgrade --quiet langchain langchain-google-genai

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
parser = StrOutputParser()

# %%
# The Prompt Template — asks the LLM to find the year AND do the math
template = ChatPromptTemplate.from_template(
    "What year was the movie '{movie}' released? "
    "Calculate how many years ago that was from 2026. "
    "Show the math briefly."

chain = template | llm | parser

# %%
# Test 1
print("🎬 Movie:The Old Guard 2")
print(chain.invoke({"movie": "The Old Guard 2"}))
# Out:
# 🎬 Movie:The Old Guard 2
# The movie 'The Old Guard 2' has not been released yet. It is currently in post-production and is expected to be released sometime in **2024 or 2025**, but an official release date and year have not been confirmed.
#
# Therefore, I cannot calculate how many years ago it was released from 2026.

# %%
# Test 2
print("🎬 Movie: Sholay")
print(chain.invoke({"movie": "Sholay"}))
# Out:
# 🎬 Movie: Sholay
# The movie 'Sholay' was released in **1975**.
#
# To calculate how many years ago that was from 2026:
#
# `2026 - 1975 = 51`
#
# So, that was **51 years ago** from 2026.

# %%
# Test 3
print("🎬 Movie: Phir Hera Pheri")
print(chain.invoke({"movie": "Phir Hera Pheri"}))
# Out:
# 🎬 Movie: Phir Hera Pheri
# The movie 'Phir Hera Pheri' was released in **2006**.
#
# To calculate how many years ago that was from 2026:
#
# 2026 - 2006 = **20 years ago**
